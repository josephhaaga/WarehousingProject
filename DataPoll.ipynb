# %%
import pandas as pd;
import http.client, urllib.request, urllib.parse, urllib.error, base64;
import datetime;

# %%
url = 'https://slickcharts.com/dowjones';
response = urllib.request.urlopen(url).read().decode('utf-8')
from bs4 import BeautifulSoup
soup = BeautifulSoup(response, 'html.parser')

raw_data = []

for row in soup.table.tbody.find_all('tr'):
#     Rank, Company, Symbol, Weight
    cells = row.find_all("td");
    rank = str(cells[0].string)
    company = str(cells[1].string)
    symbol = str(cells[2].find_all('input')[0]['value'])
    weight = str(cells[3].string)
    g = pd.Series(data = {"Rank":rank, "Company":company, "Symbol":symbol, "Weight":weight})
    g.rename(company)
    raw_data.append(g)

# %%
weights = pd.DataFrame(columns=['Rank','Company','Symbol','Weight'], data=raw_data)

# %%
# weights
# Out:
#    Rank                                      Company Symbol    Weight
# 0     1                               Boeing Company     BA  7.773790
# 1     2                     Goldman Sachs Group Inc.     GS  7.004971
# 2     3                                   3M Company    MMM  6.719875
# 3     4              UnitedHealth Group Incorporated    UNH  6.213074
# 4     5                                   Apple Inc.   AAPL  5.106287
# 5     6                       McDonald's Corporation    MCD  4.988277
# 6     7                              Home Depot Inc.     HD  4.780591
# 7     8  International Business Machines Corporation    IBM  4.421010
# 8     9                            Johnson & Johnson    JNJ  4.082752
# 9    10                             Caterpillar Inc.    CAT  4.054709
# 10   11                     Travelers Companies Inc.    TRV  3.906028
# 11   12              United Technologies Corporation    UTX  3.527168
# 12   13                          Chevron Corporation    CVX  3.424639
# 13   14                            Visa Inc. Class A      V  3.274205
# 14   15                          Walt Disney Company    DIS  2.968079
# 15   16                         JPMorgan Chase & Co.    JPM  2.884537
# 16   17                     American Express Company    AXP  2.785805
# 17   18                         Wal-Mart Stores Inc.    WMT  2.598274
# 18   19                     Procter & Gamble Company     PG  2.540729
# 19   20                        Microsoft Corporation   MSFT  2.461569
# 20   21                      Exxon Mobil Corporation    XOM  2.441414
# 21   22                               DowDuPont Inc.   DWDP  2.078035
# 22   23                             Merck & Co. Inc.    MRK  1.623812
# 23   24                            NIKE Inc. Class B    NKE  1.610959
# 24   25                            Intel Corporation   INTC  1.366467
# 25   26                            Coca-Cola Company     KO  1.341930
# 26   27                  Verizon Communications Inc.     VZ  1.331123
# 27   28                                  Pfizer Inc.    PFE  1.032883
# 28   29                           Cisco Systems Inc.   CSCO  1.004841
# 29   30                     General Electric Company     GE  0.590344

# %%
now = datetime.datetime.now()
nice_now = str(now.month) + "-" + str(now.day) + "--" + str(now.hour) + "-" + str(now.minute);
weights.to_csv("weights/"+nice_now+".csv")

# %%
# all_the_tickers = '/'.join(weights['Symbol'])

# %%
import quandl
quandl.ApiConfig.api_key = 'k_u9AcWRLYRjV4KQhh2X';

# %%
individual_tickers = {}
for ticker in weights.Symbol:
    individual_tickers[ticker] = quandl.get("WIKI/"+ticker)[-1:]

    

# individual_tickers
# Out:
# {'AAPL':               Open    High    Low   Close      Volume  Ex-Dividend  \
#  Date
#  2017-11-07  173.91  175.25  173.6  174.81  23910914.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0
0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      45.41      45.95     45.31       45.94    9787531.0  ,
#  'MCD':              Open    High     Low   Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  170.1  170.82  169.52  170.77  2479231.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0      170.1     170.82    169.52      170.77
#
#              Adj. Volume
#  Date
#  2017-11-07    2479231.0  ,
#  'MMM':               Open    High     Low   Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  230.38  230.77  229.14  230.05  1550074.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0     230.38     230.77    229.14      230.05
#
#              Adj. Volume
#  Date
#  2017-11-07    1550074.0  ,
#  'MRK':              Open    High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  55.88  56.185  55.38  55.59  14183210.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      55.88     56.185     55.38       55.59   14183210.0  ,
#  'MSFT':              Open  High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  84.77  84.9  83.93  84.27  17152583.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      84.77       84.9     83.93       84.27   17152583.0  ,
#  'NKE':              Open    High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  55.75  56.015  55.02  55.15  7356767.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      55.75     56.015     55.02       55.15    7356767.0  ,
#  'PFE':             Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  35.3  35.42  35.24  35.36  9539774.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07       35.3      35.42     35.24       35.36    9539774.0  ,
#  'PG':              Open  High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  86.04  87.0  85.42  86.98  6837186.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      86.04       87.0     85.42       86.98    6837186.0  ,
#  'TRV':               Open    High     Low   Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  133.98  134.74  133.41  133.72  1445854.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0     133.98     134.74    133.41      133.72
#
#              Adj. Volume
#  Date
#  2017-11-07    1445854.0  ,
#  'UNH':               Open    High     Low  Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  212.74  213.54  210.89  212.7  1777825.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0     212.74     213.54    210.89       212.7
#
#              Adj. Volume
#  Date
#  2017-11-07    1777825.0  ,
#  'UTX':               Open    High     Low   Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  120.67  121.46  120.38  120.75  1853601.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0     120.67     121.46    120.38      120.75
#
#              Adj. Volume
#  Date
#  2017-11-07    1853601.0  ,
#  'V':               Open     High     Low   Close     Volume  Ex-Dividend  \
#  Date
#  2017-11-07  112.25  112.469  111.56  112.09  3667438.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0     112.25    112.469    111.56      112.09
#
#              Adj. Volume
#  Date
#  2017-11-07    3667438.0  ,
#  'VZ':              Open     High    Low  Close      Volume  Ex-Dividend  \
#  Date
#  2017-11-07  45.21  45.5878  44.68  45.57  25731873.0          0.0
#
#              Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
#  Date
#  2017-11-07          1.0      45.21    45.5878     44.68       45.57
#
#              Adj. Volume
#  Date
#  2017-11-07   25731873.0  ,
#  'WMT':              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  88.87  89.06  88.31  88.95  5232777.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      88.87      89.06     88.31       88.95    5232777.0  ,
#  'XOM':              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
#  Date
#  2017-11-07  83.74  83.82  83.03  83.58  8420512.0          0.0          1.0
#
#              Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
#  Date
#  2017-11-07      83.74      83.82     83.03       83.58    8420512.0  }

# %%
# pd.DataFrame(individual_tickers['AAPL'].iloc[0])

# %%
parsed = {};
for k in individual_tickers.keys():
    parsed[k] = individual_tickers[k].iloc[0]

# %%
pd.DataFrame(parsed).to_csv("tickers/"+nice_now+".csv")

# %%
# https://finance.yahoo.com/quote/%5EDJI/history/
# DJIA Open & Close Price
